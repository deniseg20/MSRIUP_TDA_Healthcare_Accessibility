# %% [markdown]
# # Heatmap for Distance Matrix

# %%
# %pip install openpyxl 
import csv 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# setting styles
plt.style.use('default')
sns.set_palette("viridis") # inclusive color map
# Out:
# Requirement already satisfied: openpyxl in c:\users\dgonz\appdata\local\programs\python\python313\lib\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in c:\users\dgonz\appdata\local\programs\python\python313\lib\site-packages (from openpyxl) (2.0.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
matrix_data  = np.load('all_d_matrix.npy')

# %%
plt.figure(figsize=(20, 20))

sns.heatmap(matrix_data, 
            annot=False,          # Show values in cells
            cmap='viridis_r')       # Color scheme

plt.title("Basic Matrix Heatmap (all locations)", fontsize=16, fontweight='bold', pad=20)
plt.show()
